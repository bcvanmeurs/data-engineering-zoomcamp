# %%
import pandas as pd

# %%
data = pd.read_csv("green_tripdata_2019-01.csv")

# %%
condition = (data.lpep_pickup_datetime > "2019-01-15") & (data.lpep_pickup_datetime < "2019-01-16") & \
(data.lpep_dropoff_datetime > "2019-01-15") & (data.lpep_dropoff_datetime < "2019-01-16")

# %%
data[condition].shape[0]
# Out:
# 20530

# %%
data.shape[0]
# Out:
# 630918

# %%
data[condition].sort_values('lpep_pickup_datetime',ascending=False)
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 300683         2  2019-01-15 23:56:38   2019-01-15 23:59:00
# 300946         1  2019-01-15 23:55:39   2019-01-15 23:59:11
# 300771         1  2019-01-15 23:55:32   2019-01-15 23:58:26
# 300922         2  2019-01-15 23:54:54   2019-01-15 23:57:45
# 300981         2  2019-01-15 23:54:21   2019-01-15 23:59:54
# ...          ...                  ...                   ...
# 279998         2  2019-01-15 00:00:45   2019-01-15 00:07:05
# 280364         1  2019-01-15 00:00:44   2019-01-15 00:06:32
# 280344         2  2019-01-15 00:00:41   2019-01-15 00:13:38
# 280118         2  2019-01-15 00:00:34   2019-01-15 00:14:48
# 280406         2  2019-01-15 00:00:10   2019-01-15 00:03:01
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 300683                  N           1             7             7
# 300946                  N           1             7             7
# ...

# %%
data = pd.read_parquet("green_tripdata_2019-01.parquet")

# %%
data.shape[0]
# Out:
# 672105

# %%
data[condition].shape[0]
# Out:
# 22292
